# %% [markdown]
# ### Plotting is generally done in a 2-Dimensional diagram, two Popular libraries used for it are :-
# Matpoltlib
# and
# Seaborn

# %% [markdown]
# ### Color codes
# ##### Character Color
# 'b' :- Blue
#
# 'g' :- Green
#
# 'r' :- Red
#
# 'b' :- Blue
#
# 'c' :- Cyan
#
# 'm' :- Magenta
#
# 'y' :- Yellow
#
# 'k' :- Black
#
# 'b' :- Blue
#
# 'w' :- White
#
# 'Reference HTML Color Codes' -- https://html-color.codes/
#
#
# ### Marker codes
# ##### Character Description
#
# '.' :- Point marker
#
# 'o' :- Circle marker
#
#
# 'x' :- X marker
#
#
# 'D' :- Diamond marker
#
# 'H' :- Hexagon marker
#
# 's' :- Square marker
#
# '+' :- Plus marker
#
# '^' :- Triangle
#
#
# ### Line styles
# ##### Character Description
#
# '-' :- Solid line
#
# '—' :- Dashed line
#
# '-.':- Dash-dot line
#
# ':' :- Dotted line

# %% [markdown]
# ### Matplot Library

# %%
import warnings
warnings.filterwarnings( "ignore")

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Bivariate Data

# %% [markdown]
# ### a. Line Plot

# %%
x = [1,2,3,4,5,6,7]
y = [1,4,9,16,25,36,49]
z = [1,8,27,64,125,216,343]

# %%
plt.figure(figsize = (5,5)) ## To control the size of figure
plt.title('Line Plot',fontsize =15) ## Specifies Title of Plot
plt.xlabel('X-Values') ## Specifes the X-labels
plt.ylabel('Y-Values') ## Specifes the Y-labels

plt.plot(x,y,color = 'blue',
         linestyle = 'dashdot',
        marker = '^',
        markersize = 12,
        markerfacecolor = '#b3be54') ## This is ploting the data
plt.show()    ## This plots as per matplotlib's way

# %% [markdown]
# ### Plotting more than one Curve in the Same figure

# %%
### Some Hypothetical plot
plt.figure(figsize = (5,5))
plt.title('Line Plot',fontsize =15)
plt.xlabel('Decades')
plt.ylabel('Social Maturity')

## Plot for Cube of Numbers
plt.plot(x,z,color = 'orange',
         linestyle = 'solid',
        marker = '^',
        markersize = 10,
        markerfacecolor = '#581fd2',
        label = 'India')

## Plot for Square of Numbers
plt.plot(x,y,color = 'blue',
         linestyle = 'dashdot',
        marker = 'H',
        markersize = 10,
        markerfacecolor = '#b3be54',
        label = 'Pakistan')


plt.legend()
plt.show()

# %% [markdown]
# ### b.Scatter Plot

# %%
price = pd.read_csv('datasets/scatter_data.csv')
price.head()
# Out:
#      ID  Building Type  Year of sale  Month of sale Type of property  \
# 0  1030              1        2005.0           11.0        Apartment
# 1  1029              1        2005.0           10.0        Apartment
# 2  2002              2        2007.0            7.0        Apartment
# 3  2031              2        2007.0           12.0        Apartment
# 4  1049              1        2004.0           11.0        Apartment
#
#    Property #  Area (ft.)      Price  Status
# 0          30      743.09  246.17268   Sold
# 1          29      756.21  246.33190   Sold
# 2           2      587.28  209.28091   Sold
# 3          31     1604.75  452.66701   Sold
# 4          49     1375.45  467.08331   Sold

# %% [markdown]
# #### Rename Columns within DataFrame

# %%
price.rename(columns = {'Area (ft.)':'Area','Year of sale':'SaleYear'},inplace = True)
price.head()
# Out:
#      ID  Building Type  SaleYear  Month of sale Type of property  Property #  \
# 0  1030              1    2005.0           11.0        Apartment          30
# 1  1029              1    2005.0           10.0        Apartment          29
# 2  2002              2    2007.0            7.0        Apartment           2
# 3  2031              2    2007.0           12.0        Apartment          31
# 4  1049              1    2004.0           11.0        Apartment          49
#
#       Area      Price  Status
# 0   743.09  246.17268   Sold
# 1   756.21  246.33190   Sold
# 2   587.28  209.28091   Sold
# 3  1604.75  452.66701   Sold
# 4  1375.45  467.08331   Sold

# %%
plt.figure(figsize = (5,5))
plt.title('House Prices')
plt.xlabel('Area In Sq. Ft')
plt.ylabel('Price')
plt.scatter(price['Area'],price['Price'],
           color = '#00ff00',
            edgecolor = '#ffebcd',
           marker = 'H',
           s=20)
plt.show()

# %%
CarsListings = pd.read_csv('datasets/bar_chart_data.csv')
CarsListings.head()
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438

# %%
CarsListings.rename(columns = {'Cars Listings' : 'Listings'},inplace = True)
CarsListings.head()
# Out:
#            Brand  Listings
# 0           Audi       419
# 1            BMW       636
# 2  Mercedes-Benz       820
# 3     Mitsubishi       306
# 4        Renault       438

# %% [markdown]
# ## Numerical V/s Categorical Data
# ### a.BarChart

# %%
plt.figure(figsize = (10,5))
plt.title("Cars Listed For Each Brand", fontdict = {
    'fontsize' : 14,
    'color': '#b0c24a'})
plt.bar(CarsListings['Brand'],
        CarsListings['Listings'],
       color = '#ccff00') # the bar() function is plotting the bar chart
plt.xticks(fontsize = 10 
           ,rotation = 45
          )
plt.show()

# %% [markdown]
# ## b.The horizontal Bar

# %%
plt.figure(figsize = (10,5))
plt.title("Cars Listed For Each Brand")
plt.barh(CarsListings['Brand'],
        CarsListings['Listings'],
       color = '#ee82ee')
plt.yticks(fontsize = 14
          )
plt.xticks(fontsize = 14 
           ,rotation = 45
          )
plt.show()

# %% [markdown]
# ## Pie Plot

# %%
plt.pie(CarsListings['Listings'],
       labels = CarsListings['Brand'],
        autopct = '%0.1f%%',
        textprops={'fontsize':10,'color':'#000039'},
        explode = (0,0,0,0,0,0,0.1)
       )
plt.show()

# %% [markdown]
# ### Univariate Data

# %% [markdown]
# #### Box Plot

# %%
price['Price'].describe()
# Out:
# count    267.000000
# mean     281.171901
# std       89.119121
# min      117.564070
# 25%      217.553055
# 50%      249.075660
# 75%      326.964855
# max      538.271740
# Name: Price, dtype: float64

# %%
plt.boxplot(price['Price'])
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.hist(price['Price'],
        bins = 15,
        color = '#008b8b',
        edgecolor = '#fdf5e6')
plt.show()

# %%
import seaborn as sns

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = pd.read_csv('datasets/tips.csv')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Cat plot
# 1. Bar Plot

# %%
df_cars = pd.read_csv('datasets/bar_chart_data.csv')
df_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %% [markdown]
# ## Seaborn Works Hand in Hand with matplotlib

# %%
# pal = sns.color_palette('viridis')
sns.catplot(df_cars,x = 'Brand',y = 'Cars Listings',
            kind = 'bar',
            aspect =2/1,
           palette = sns.color_palette('viridis') # Can pass pal also 
           ) ## Plots
plt.show() # Renders the Plot

# %% [markdown]
# ## Horizontal bar is not supported in seaborn but can be obtained interchanging x and y in bar plot

# %%
# pal = sns.color_palette('viridis')
sns.catplot(df_cars,x = 'Cars Listings',y = 'Brand',
            kind = 'bar',
            # aspect =2/1,
           palette = sns.color_palette('viridis') # Can pass pal also 
           ) ## Plots
plt.show() # Renders the Plot

# %% [markdown]
# ### Box Plot

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill',
           kind = 'box')
plt.show()

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill',
           kind = 'box',
           hue = 'time')
plt.show()

# %% [markdown]
# ## Strip plot

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill',
           kind = 'strip',
           # hue = 'time',
        palette = 'Set2'
           )
plt.show()

# %% [markdown]
# ## Swarm Plot

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill',
           kind = 'swarm', 
           # hue = 'time',
           palette = 'Set2'
           )
plt.show()

# %% [markdown]
# ### Relplot

# %%
mpg = pd.read_csv('datasets/mpg.csv')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### line plot

# %%
sns.relplot(data=mpg, x = 'model_year', y = 'mpg',
           kind = 'line',
           ci = False,
           palette = 'Set2',
           hue = 'origin',
           style = 'origin')
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
sns.relplot(data=tips,x='total_bill', y = 'tip',
           hue = 'sex',kind ='scatter')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data = tips, palette = 'viridis')
plt.show()

# %% [markdown]
# ## Univariate Data

# %%
sns.histplot(data=tips, x='total_bill',bins=10)
plt.show()

# %%
sns.histplot(data=tips, x='total_bill',bins=10,
            element = 'step',fill = False,
            color = 'black')
plt.show()

# %% [markdown]
# ## KDE Plot - probability Distribution plot

# %%
sns.kdeplot(data=tips,x='total_bill',color = 'brown', fill = True)
plt.show()
