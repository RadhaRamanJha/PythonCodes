# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_excel("/content/ContractRenewal_Data(unstacked).xlsx")

# %%
df
# Out:
#      Supplier A  Supplier B  Supplier C
# 0          6.15        7.87        7.41
# 1          6.22        5.21        3.61
# 2          6.76        7.94        7.23
# 3          4.29        7.36        5.53
# 4          7.08        6.17        3.97
# ..          ...         ...         ...
# 115        5.85        4.53        4.27
# 116        5.04        8.06        6.39
# 117        5.68        7.14        4.60
# 118        4.77        4.84        6.15
# 119        3.57        4.55        5.28
#
# [120 rows x 3 columns]

# %%
#h0: all supplier means are same
#h1: atleast one mean is different

# %%
stats.f_oneway(df["Supplier A"],df["Supplier B"],df["Supplier C"])
# Out:
# F_onewayResult(statistic=2.280378701368123, pvalue=0.10373295731933224)

# %%
#h0: proportion of defects is same
#h1: atleast one proportion is different

df1 = pd.read_excel("prop_defect.xlsx")

# %%
df1
# Out:
#     defects country
# 0         0     IND
# 1         0     IND
# 2         0     IND
# 3         1     IND
# 4         0     IND
# 5         1     IND
# 6         1     IND
# 7         0     IND
# 8         1     IND
# 9         0     IND
# 10        0     IND
# 11        1     AUS
# 12        0     AUS
# 13        1     AUS
# 14        1     AUS
# 15        0     AUS
# 16        0     AUS
# 17        0     AUS
# 18        0     AUS
# 19        1     AUS
# 20        0     AUS
# 21        1     AUS
# 22        0     AUS
# 23        0     AUS
# 24        0     AUS
# 25        1     AUS
# 26        1     USA
# 27        1     USA
# 28        1     USA
# 29        0     USA
# 30        0     USA
# 31        1     USA
# 32        1     USA
# 33        0     USA
# 34        1     USA
# 35        0     USA
# 36        0     USA
# 37        1     USA
# 38        0     USA
# 39        1      SL
# 40        1      SL
# 41        0      SL
# 42        0      SL
# 43        0      SL
# ...

# %%
df1["country"].unique()
# Out:
# array(['IND', 'AUS', 'USA', 'SL'], dtype=object)

# %%
df2 = pd.crosstab(df1["defects"],df1["country"])

# %%
df2
# Out:
# country  AUS  IND  SL  USA
# defects
# 0          9    7   8    6
# 1          6    4   7    7

# %%
stats.chi2_contingency(df2)
# Out:
# Chi2ContingencyResult(statistic=0.9062937062937066, pvalue=0.8239087332608883, dof=3, expected_freq=array([[8.33333333, 6.11111111, 8.33333333, 7.22222222],
#        [6.66666667, 4.88888889, 6.66666667, 5.77777778]]))

# %%
stats.chi2.ppf(0.95,3)
# Out:
# 7.814727903251179
